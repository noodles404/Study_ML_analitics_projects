# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет, меня зовут Александр Куимов. Я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь реагировать на мои комментарии своими по шаблону, показанному чуть ниже. Это нужно, чтобы не создавалась путаница😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
#
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> В такой цветовой ячейке я прошу тебя оставлять свои комментарии. Если исправляешь проект на второй итерации и выше, не забывай пожалуйста указывать номер итерации, например, "Комментарий студента v.2".
# </div>
#
# <br/>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе датасаентистом. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка</a></span><ul class="toc-item"><li><span><a href="#Ресемплирование-по-часу" data-toc-modified-id="Ресемплирование-по-часу-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Ресемплирование по часу</a></span></li></ul></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ</a></span><ul class="toc-item"><li><span><a href="#Тренды,-сезонность,-остатки" data-toc-modified-id="Тренды,-сезонность,-остатки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Тренды, сезонность, остатки</a></span></li><li><span><a href="#Разность-временного-ряда" data-toc-modified-id="Разность-временного-ряда-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Разность временного ряда</a></span></li><li><span><a href="#Вывод-по-анализу" data-toc-modified-id="Вывод-по-анализу-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Вывод по анализу</a></span></li></ul></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Медиана-предыдущей-выборки" data-toc-modified-id="Медиана-предыдущей-выборки-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Медиана предыдущей выборки</a></span></li><li><span><a href="#Предыдущеее-знчение-ряда" data-toc-modified-id="Предыдущеее-знчение-ряда-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>Предыдущеее знчение ряда</a></span></li><li><span><a href="#Feature-engeniring" data-toc-modified-id="Feature-engeniring-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>Feature engeniring</a></span></li><li><span><a href="#Обучение-и-тестирование-нескольких-моделей-с-градиентным-бустингом" data-toc-modified-id="Обучение-и-тестирование-нескольких-моделей-с-градиентным-бустингом-3.0.4"><span class="toc-item-num">3.0.4&nbsp;&nbsp;</span>Обучение и тестирование нескольких моделей с градиентным бустингом</a></span></li></ul></li><li><span><a href="#Визуализация-тестовых-и-предсказанных-значений" data-toc-modified-id="Визуализация-тестовых-и-предсказанных-значений-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Визуализация тестовых и предсказанных значений</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %%
# !pip install --upgrade scikit-learn -q

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
import random
import math
import calendar


from sklearn.model_selection import train_test_split, GridSearchCV, TimeSeriesSplit, cross_val_score
from sklearn.preprocessing import (StandardScaler, 
                                   MinMaxScaler, 
                                   RobustScaler,
                                   PolynomialFeatures, 
                                   OneHotEncoder,
                                   OrdinalEncoder, 
                                   LabelEncoder)


from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer


from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error ,mean_absolute_error, r2_score, make_scorer, root_mean_squared_error


from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor

# %% [markdown]
# ## Подготовка

# %%
data = pd.read_csv('/datasets/taxi.csv')
data.head()
# Out:
#               datetime  num_orders
# 0  2018-03-01 00:00:00           9
# 1  2018-03-01 00:10:00          14
# 2  2018-03-01 00:20:00          28
# 3  2018-03-01 00:30:00          20
# 4  2018-03-01 00:40:00          32

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26496 entries, 0 to 26495
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    26496 non-null  object
#  1   num_orders  26496 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 414.1+ KB

# %%
data.isna().sum()
# Out:
# datetime      0
# num_orders    0
# dtype: int64

# %%
data['date'] = data.datetime.astype('datetime64')
data.drop('datetime', axis=1, inplace=True)
data.head()
# Out:
#    num_orders                date
# 0           9 2018-03-01 00:00:00
# 1          14 2018-03-01 00:10:00
# 2          28 2018-03-01 00:20:00
# 3          20 2018-03-01 00:30:00
# 4          32 2018-03-01 00:40:00

# %%
data.set_index('date', inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %% [markdown]
# Не помешает проверить индекс на хронологический порядок даты и времени

# %%
data = data.sort_index()
print(data.index.is_monotonic_increasing)
# Out:
# True

# %% [markdown]
# ### Ресемплирование по часу

# %%
data.resample('1H').sum().plot(figsize=(15, 8))
plt.title('График числа заказов от по месяцам, ресэмплированный по часу')
# Out:
# Text(0.5, 1.0, 'График числа заказов от по месяцам, ресэмплированный по часу')

# %% [markdown]
# Добавим скользящее среднее с окном, равным 10, и вычислим среднее значение для сглаживания графика

# %%
temp_df = data.resample('1H').sum()
temp_df['rolling_mean'] = temp_df.rolling(10).mean() 
temp_df.plot(figsize=(15, 8))
plt.title('График числа заказов от по месяцам, ресэмплированный по часу')
# Out:
# Text(0.5, 1.0, 'График числа заказов от по месяцам, ресэмплированный по часу')

# %%
data_resampled = data.resample('1H').sum()

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# С данными познакомились, проведен первичный аналитический осмотр!) Отлично, что проведено ресемплирование с использованием суммы. Полученная информация поможет нам в дальнейшем с предобработкой данных

# %% [markdown]
# ## Анализ

# %% [markdown]
# ### Тренды, сезонность, остатки

# %%
temp_df = data.resample('1H').sum()

decomposed = seasonal_decompose(temp_df) 

plt.figure(figsize=(12, 8))
plt.subplot(311)

decomposed.trend.plot(ax=plt.gca())
plt.title('Trend')

plt.subplot(312)
decomposed.seasonal.plot(ax=plt.gca()) 
plt.title('Seasonality')

plt.subplot(313)
decomposed.resid.plot(ax=plt.gca()) 
plt.title('Residuals')
plt.tight_layout()

# %% [markdown]
# На графике тренда происходит постпутаельный рост числа заказов в с минимумов марта и апреля и достижение максимумов в августе

# %% [markdown]
# Изучим тренды и сезонность по каждому месяцу по отдельности

# %%
def plot_trend_seasonality(temp_df, month_name):

    decomposed = seasonal_decompose(temp_df) 

    plt.figure(figsize=(12, 8))
    plt.subplot(211)

    decomposed.trend.plot(ax=plt.gca())
    plt.title(f'Тренд числа заказов для месяца {month_name}')

    plt.subplot(212)
    decomposed.seasonal.plot(ax=plt.gca()) 
    plt.title(f'Сезонность числа заказов для месяца {month_name}')

# %%
for month in data.index.month.unique():
    temp_df = data[f'2018-{month}-01': f'2018-{month}-30' ].resample('1H').sum()
    month_name = calendar.month_name[month]

    plot_trend_seasonality(temp_df, month_name)

# %% [markdown]
# Тренды и сезонность по месяцам практически не меняются, растет только величина целевого признака

# %% [markdown]
# Изучим сезонность по одному весеннему(апрель) и одному летнему(июль) месяцу с разными датами, возьмем 1, 8, 18, 30 числа

# %%
def plot_seasonality_per_day(temp_df, month, day_num):

    decomposed = seasonal_decompose(temp_df) 

    plt.figure(figsize=(12, 4))
   
    decomposed.seasonal[f'2018-{month}-{day_num} 00:00:00': f'2018-{month}-{day_num} 23:59:59'].plot(ax=plt.gca()) 
    plt.title(f'Сезонность числа заказов по часам для {day_num}th  {month_name}')

for month in [4,7]:
    temp_df = data[f'2018-{month}-01': f'2018-{month}-30'].resample('1H').sum()
    month_name = calendar.month_name[month]

    for day_num in [1,8,18,30]:
        plot_seasonality_per_day(temp_df, month_name, day_num)

# %% [markdown]
# Сезонность заказов каждый час для в любой из дней, что в весеннем, что в летнем месяце практически идентична:
# - повышенный спрос между 21:00 и 3:00
# - резкое падение после 0:00 и минимальное кол-во заказов между 4 и 7 утра
# - средние показатели без сильной волательности с 9 до 18

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Декомпозиция сделана верно. Хорошо, что сезонность была визуализирована на более коротком интервале)

# %% [markdown]
# ### Разность временного ряда

# %% [markdown]
# На данном этапе я построю стационарный ряд, за счет сдвигов

# %%
temp_df = data.resample('1H').sum()

temp_df = temp_df - temp_df.shift(fill_value=0)  

temp_df['mean'] = temp_df['num_orders'].rolling(15).mean()
temp_df['std'] = temp_df['num_orders'].rolling(15).std()

temp_df.plot(figsize=(12,6))
plt.title('График числа заказов по стационарному временному ряду, ресэмплированный по часу')

plt.show()

# %% [markdown]
# Разброс скользящей средней нахится в пределах околонулевых значений, именно этот временной ряд можно назвать стационарным и он лучше всего подойдет для прогнозирования в дальнейшем.

# %% [markdown]
# ### Вывод по анализу

# %% [markdown]
# 1) Ежемесячный тренд стабильный и восходящий от весенних месяцев к летним, пиковые значения достигаются в августе
#
# 2) Логика сезонности заказов не меняется от месяца к месяцу
#
# 3) Логика почасовой сезонности также неизменна:
#
#     - повышенный спрос между 21:00 и 3:00
#     - резкое падение после 0:00 и минимальное кол-во заказов между 4 и 7 утра
#     - средние показатели без сильной волатильности с 9 до 18
#
# 4) Разность по временному ряду сделала его более стационарным - подходит для прогнозирования

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Анализ проведен корректно. Отлично, что обнаружен тренд на рост числа заказов)

# %% [markdown]
# ## Обучение

# %% [markdown]
# #### Медиана предыдущей выборки

# %%
train, test = train_test_split(data_resampled, shuffle=False, test_size=0.1)

print("Среднее число заказов в час:", test['num_orders'].mean())

pred_median = np.ones(test.shape) * train['num_orders'].median()

print("RMSE:", root_mean_squared_error(test, pred_median))
# Out:
# Среднее число заказов в час: 139.55656108597285
# RMSE: 87.15277582981295

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Доля тестовой выборки по условию должна составлять 10% от полной

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Сейчас использована не нужная нам метрика, cледует использовать `RMSE`. Исправь, пожалуйста

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# #### Предыдущеее знчение ряда

# %%
train, test = train_test_split(data_resampled, shuffle=False, test_size=0.1)

print("Среднее число заказов в час:", test['num_orders'].mean())

pred_previous = test.shift(fill_value=train.iloc[-1,-1])

print("RMSE:", root_mean_squared_error(test, pred_previous))
# Out:
# Среднее число заказов в час: 139.55656108597285
# RMSE: 58.856486242815066

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Доля тестовой выборки по условию должна составлять 10% от полной

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Просчитался, но где... Спасибо, исправил)
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Сейчас использована не нужная нам метрика, cледует использовать `RMSE`. Исправь, пожалуйста

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Сейчас подправлю)
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# #### Feature engeniring
#
#     - признаки разделенных календарных значений
#     - разности
#     - скользящие средние

# %%
def make_features(data, max_lag, rolling_mean_size):
    data['month'] = data.index.month
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    data['hour'] = data.index.hour
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)
    
    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# При генерации новых признаков желательно написать функцию, чтобы она возвращала новый датафрейм, а не изменяла глобальную переменную.
#
# 1. Это хорошая практика (не изменять глобальные переменные внутри функции), которая улучшает читаемость кода.
# 2. В какой-то момент может появиться необходимость подбирать некоторые параметры используемые внутри функции. В этот момент копирование датасета станет обязательным.
#
#
#
#
# Для этого внутри, в начале функции нужно задать новое имя датафрейму с `df.copy()`, в нем создать новые признаки, а в конце функции возвращать через `return` этот датафрейм
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Оптимальное решение, буду использовать
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
make_features(data_resampled, 2, 2)
print(data_resampled.head())
# Out:
#                      num_orders  month  day  dayofweek  hour  lag_1  lag_2  \
# date
# 2018-03-01 00:00:00         124      3    1          3     0    NaN    NaN
# 2018-03-01 01:00:00          85      3    1          3     1  124.0    NaN
# 2018-03-01 02:00:00          71      3    1          3     2   85.0  124.0
# 2018-03-01 03:00:00          66      3    1          3     3   71.0   85.0
# 2018-03-01 04:00:00          43      3    1          3     4   66.0   71.0
#
#                      rolling_mean
# date
# 2018-03-01 00:00:00           NaN
# 2018-03-01 01:00:00           NaN
# 2018-03-01 02:00:00         104.5
# 2018-03-01 03:00:00          78.0
# 2018-03-01 04:00:00          68.5

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
#
# Метрика на тесте должна быть ниже 48, поэтому стоит попробовать задать параметр max_lag равным 24 при создании новых признаков функцией. В случае заказов такси самая очевидная сезонность - внутри суток, а в сутках 24 часа, это значение и будет оптимальным. Размер окна тоже можно увеличить

# %% [markdown]
# #### Обучение и тестирование нескольких моделей с градиентным бустингом

# %% [markdown]
#  - Сдвиг 24, т.е 24 часа в сутках;
#  - размер окна скользящего среднего 2.

# %%
data_resampled = data.resample('1H').sum()

make_features(data_resampled, max_lag=24, rolling_mean_size=2)    

train, test = train_test_split(data_resampled, shuffle=False, test_size=0.1)
train = train.dropna()

X_train = train.drop('num_orders', axis=1)
y_train = train['num_orders']

X_test = test.drop('num_orders', axis=1)
y_test = test['num_orders']

num_cols = X_train.columns

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Хорошо, что деление происходит последовательно по времени

# %%
column_transformer = ColumnTransformer(
    [
        ('num', StandardScaler(), num_cols)
    ],
    remainder='passthrough'
)

# %%
final_pl = Pipeline(
    [
        ('preprocessor', column_transformer),
        ('models', DecisionTreeRegressor(random_state=42))
    ]
)

# %%
params = [
    {
        'models': [CatBoostRegressor(random_state=42, verbose=10), 
                   LGBMRegressor(random_state=42)],
        'models__learning_rate':  [0.1, 0.25], 
        'models__max_depth': [10, 12],
        'models__n_estimators': [200], 
        'preprocessor__num': ['passthrough']
    },
    {
        'models': [DecisionTreeRegressor(random_state=42)],
        'models__max_depth': range(3, 5),
        'models__min_samples_split': range(3, 5),
        'models__min_samples_leaf': range(3, 5),
        'preprocessor__num': ['passthrough']
    }
]

# %%
gscv = GridSearchCV(final_pl,
    cv=TimeSeriesSplit(n_splits=5),# из-за хронологического порядка данных кросс-валидация не подходит, следует использовать TimeSeriesSplit
    param_grid=params,
    n_jobs=-1,
    scoring='neg_root_mean_squared_error')

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Отлично, что применяется TimeSeriesSplit, а не простой сплиттер

# %%
gscv.fit(X_train, y_train)
# Out:
# 0:	learn: 28.5430446	total: 95.8ms	remaining: 19.1s
# 10:	learn: 19.9827911	total: 402ms	remaining: 6.9s
# 20:	learn: 15.4987408	total: 676ms	remaining: 5.76s
# 30:	learn: 12.9766158	total: 953ms	remaining: 5.2s
# 40:	learn: 11.1483118	total: 1.24s	remaining: 4.81s
# 50:	learn: 9.5748761	total: 1.52s	remaining: 4.43s
# 60:	learn: 8.3849613	total: 1.8s	remaining: 4.1s
# 70:	learn: 7.3506761	total: 2.08s	remaining: 3.78s
# 80:	learn: 6.4878828	total: 2.39s	remaining: 3.51s
# 90:	learn: 5.8477024	total: 2.69s	remaining: 3.23s
# 100:	learn: 5.2879248	total: 2.99s	remaining: 2.93s
# 110:	learn: 4.7339329	total: 3.28s	remaining: 2.63s
# 120:	learn: 4.1211535	total: 3.55s	remaining: 2.32s
# 130:	learn: 3.5784753	total: 3.85s	remaining: 2.03s
# 140:	learn: 3.2086097	total: 4.12s	remaining: 1.72s
# 150:	learn: 2.9230248	total: 4.41s	remaining: 1.43s
# 160:	learn: 2.5613337	total: 4.69s	remaining: 1.14s
# 170:	learn: 2.3171722	total: 4.98s	remaining: 844ms
# ...

# %%
gscv.best_estimator_
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', 'passthrough',
#                                                   Index(['month', 'day', 'dayofweek', 'hour', 'lag_1', 'lag_2', 'lag_3', 'lag_4',
#        'lag_5', 'lag_6', 'lag_7', 'lag_8', 'lag_9', 'lag_10', 'lag_11',
#        'lag_12', 'lag_13', 'lag_14', 'lag_15', 'lag_16', 'lag_17', 'lag_18',
#        'lag_19', 'lag_20', 'lag_21', 'lag_22', 'lag_23', 'lag_24',
#        'rolling_mean'],
#       dtype='object'))])),
#                 ('models',
#                  <catboost.core.CatBoostRegressor object at 0x7f0ca91001f0>)])

# %% [markdown]
# Прогнозирование без обучения

# %%
model_boost = gscv.best_estimator_
print("RMSE тестовой выборки:", root_mean_squared_error(y_test, model_boost.predict(X_test)))
# Out:
# RMSE тестовой выборки: 45.45464372180812

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Знай, что тестирование положено проводить для одной лучшей модели. На этом шаге мы должны были настроить модели и выбрать одну наилучшую, опираясь на метрики данные заказчиком (это может быть качество, время обучения, скорость предсказания и т.д.). Тестированием мы моделируем работу модели на новых незнакомых ей данных, которые ни разу не использовались ни при тренировке, ни при валидации, и проверяем, не словили ли мы переобучение. А эти данные могут быть смещенными, с выбросами и т.д. То есть по таким данным некорректно заново переопределять модель-победитель.  Советую тебе статью, рассматривающую разные способы валидации моделей машинного обучения: https://towardsdatascience.com/validating-your-machine-learning-model-25b4c8643fb7 (нужен VPN)
#
# Метрики качества на тестовой выборке для всех моделей можно вычислить только с целью исследования их смещения относительно аналогичных метрик на кросс-валидации/ валидационной выборке. Но это не означает, что модель-победитель должна выбираться исходя из сравнения метрик, полученных на тестовой выборке.

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Усвою
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# Не подходит

# %% [markdown]
# Прогнозирование с обучением

# %%
final_model = LGBMRegressor(max_depth=3, n_estimators=200, random_state=1234, num_leaves=10, force_col_wise=True, verbosity=-1)

final_model.fit(X_train, y_train)

print("RMSE тестовой выборки:", root_mean_squared_error(y_test, final_model.predict(X_test)))
print("MAE тестовой выборки:", mean_absolute_error(y_test, final_model.predict(X_test)))
# Out:
# RMSE тестовой выборки: 39.67678325972011
# MAE тестовой выборки: 29.127091285703166

# %% [markdown]
# Лучшая модель LGBMRegressor
#
# RMSE на тестовой выборке равен 39.67, т.е 40 заказов, что в пределах установленного лимита в 48.
#
# MAE всего 29, однако это не целевая метрика, для оценки качества прогноза

# %% [markdown]
# ### Визуализация тестовых и предсказанных значений

# %%
pred_vis = final_model.predict(X_test)

fig, ax = plt.subplots(figsize=(16, 6)) 

ax.plot(y_test.index,
    y_test.values,
    linewidth = 2,
    label = 'Тестовые данные',
    color='green')

ax.plot(y_test.index,
    pred_vis,
    linewidth = 2,
    label = 'Спрогнозированные данные',
    color='red' )
        
ax.set_title(f'График сравнения предсказанных и истинных данных' + "\n", fontsize = 14, color = 'Black')

plt.ylabel(f'Кол-во заказов', fontsize=12)
plt.xlabel(f'Дата', fontsize=12)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12, rotation=70);
ax.legend()
    
plt.show()

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Отлично, что  визуализированы результаты, показаны предсказанные значения лучшей модели и реальные тестовые

# %% [markdown]
# ## Вывод

# %% [markdown]
#  1) В рамках работы над проектом были собраны и проанализированы данные о заказах такси за период с марта по август 2018 года:
#
#     -данные подготовлены для дальнейшей работы;
#     -выполнено ресэмплирование по часу для прогнозирования потребности такси на следующий час.
#
#  2) Проведен анализ данных:
#
#     -тренд демонстрирует рост потребности от весенних месяцев к летним, с пиком в августе;
#     -сезонность по месяцам выражена монотонно;
#     -почасовая сезонность заказов в разные дни весенних и летних месяцев практически одинаковая: повышенный спрос наблюдается с      21:00 до 3:00, резкий спад - с 4 до 7 утра, отскок от минимальных значений начиная с 8 утра, средний спрос - с 9 до 17      часов;
#     -разность временного ряда приближает его к стационарности и делает наиболее подходящим для прогнозирования (скользящее      среднее близко к нулю).
#
#  3) Прогнозирование выполнено двумя способами:
#
#     -без обучения модели;
#     -с обучением модели.
#
#  4) Обучение модели было выполнено:
#
#     -подбором среди 3 моделей: две модели градиентного бустинга и одна модель решающих деревьев.
#
#
#  5) Итогом подбора лучшей модели стала модель LGBMRegressor, ее метрики составили:
#
#     -MAE = 29 заказов;
#     -целевая RMSE = 40 заказов.
#     -Показатели лучшей модели удовлетворяют требованиям заказчика.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера <a class="tocSkip"> </h2>
#
#
# У меня сложилось хорошее общее впечатление о проекте, тебе удалось неплохо справиться с этим проектом. Молодец! Подготовлены данные для анализа, изучен каждый параметр. Все красиво визуализировано, построено несколько моделей регрессии и оценено их качество. Осмысленная аналитика и дельная модельная работа - многое удалось как надо)
#
# Отмечу отдельные положительные моменты проекта🙂:
#
# - в ходе проекта встречались  функции, помогающие избавиться от дублирования кода;
# - много красивых визуализаций в проекте и хорошая интерпретация;
# - при обучении моделей использована валидация и поиск гиперпараметров.
#
# Есть несколько моментов всего, на которые стоит ещё раз взглянуть, я указал их в моих комментариях по ходу проекта. Предлагаю тебе доработать проект по моим комментариям, чтобы довести его до совершенства.
#
#
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2>  Итоговый комментарий ревьюера 2 (итоговый вывод по проекту) <a class="tocSkip"> </h2>
#
#
#
# Теперь почти идеально. Принимаю работу)
#
# Если хочешь лучше разобраться в теме, то могу посоветовать тебе:
#
# Полезная лекция про временные ряды: https://www.youtube.com/watch?v=u433nrxdf5k
#
# Б.Б. Демешев - временные ряды https://disk.yandex.ru/i/LiDHB-B3A6Lz5A
#
# Базовое применение ARIMA - https://colab.research.google.com/drive/17RnG91Eq8JBKyxToNzvCvjibfxum-oPj?usp=sharing
#
# Канторович - Анализ временных рядов https://yadi.sk/i/IOkUOS3hTXf3gg
# https://facebook.github.io/prophet/
#
# https://facebook.github.io/prophet/docs/quick_start.html#python-api
#
# https://nbviewer.jupyter.org/github/miptgirl/habra_materials/blob/master/prophet/habra_data.ipynb
#
#
#
# В этом проекте были отработаны все моменты.
#
# Успехов тебе в следующем спринте!
#
# Рад был помочь тебе)
#
# </div>

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Данные загружены и подготовлены
# - [x]  Данные проанализированы
# - [x]  Модель обучена, гиперпараметры подобраны
# - [x]  Качество моделей проверено, выводы сделаны
# - [x]  Значение *RMSE* на тестовой выборке не больше 48
