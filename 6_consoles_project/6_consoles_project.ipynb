# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Артем, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №3__
#
# Артем, привет.     Некоторые блоки кода не работают. Посмотри, пожалуйста, что пошло не так. Перед отправкой проекта стоит проверять работоспособность кода - это можно сделать, нажав на панели Jupiter Hub Kernel и Restart & Run All
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1

# %% [markdown]
#  Проект по аналитике данных для интернет-магазина «Стримчик».
#
#  Основная задача - комплексное исследование датасета с данными об продажах игр и предоставление рекомендаций, для формирования компании стратегии продаж на 2017 год.
#
#  План:
#
#       1) Изучение данных, оценка предстоящего обьема работ по основным категорям данных(названия игр, платформы, дата релиза игровых платформ, жанры игр, продажи по регионам, оценки и игровой рейтинг).
#
#       2) Предобработка данных, анализ и удаление пропусков, описание неявных пропусков, работа с дубликатами и по необходимости их удаление, изменение типов данных при необходимости для проведения корректных вычислений, ввод новой колонки датафрейма с общими-совокупными продажами по регионам.
#
#       3) Исследование данных, построение распределния, отражающего изменение продаж по годам, построение визуализаци ежегодных продаж игр на платформах для:
#
#                       a) Определния актуального периода исследования.
#                       б) Поиска наиболее популярных платформ, подходящих для этого периода.
#                       в) Подготовка общих рекомендаций по продажам.
#
#        Далее необходимо определить, как оценки пользователей и критиков влияют на объем продаж. Затем поиск наиболее популярных жанров игр для пользователй из регионов(америка, европа, Япония) со стабильными высокими продажами  с помощью диаграммы размаха.
#
#        4) Проверка ключевых гипотез для исследования.
#
#        5) Подготовка грамотных выводов и рекомендаций для компании.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# А почему сразу не описать?

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте).
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import seaborn as sns

# %%
data = pd.read_csv('/datasets/games.csv')
data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Предлагаю разделять логически разные вещи:
#
#
#     - открытие данных (это может быть не тривиальный процесс)
#     - рабочий код
#
# Такой подход позволит улучшить читаемость кода, снизит время поиска ошибок если они есть и исключит повторное выполнение кода

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Не изучена общая информация о каждом датафрейме с помощью метода `info()`

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо бы как нибудь прокомментировать полученные данные в разделе
# </div>

# %% [markdown]
# ### 2

# %%
data.columns = data.columns.str.lower()
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# В данных может быть более 100 столбцов, и за всеми аналитику тяжко уследить. Данный способ существенно облегчает жизнь =)

# %%
#check gap
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
data['user_score'].unique()
data['user_score'] = data['user_score'].replace('tbd', '')
data['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', '', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Верно, tbd по смыслу то же, что и пропуск</div>

# %% [markdown]
# Убрал tbd, эта пометка обозначает, что рейтинг не определён. В таком случае некорректно заменять значения tbd на медианное, поскольку продукт не имеет рейтинга вовсе, поэтому логично заменить на NaN. Да потеря значащих строк крупная, 25%, но иначе сдвиг медианных значений в датасете будет слишком велик, к тому же пропусков в колонке с оценками критиков также очень много, целых 7 тысяч.

# %%
data['user_score'] = pd.to_numeric(data['user_score'], errors='ignore')
data['user_score'] = data['user_score'].astype('float')
data.head(5)
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN    NaN
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 4      8.89     10.22         1.00           NaN         NaN    NaN

# %%
data['critic_score'].unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 35., 41., 36., 28., 31., 27., 26., 19., 23.,
#        24., 21., 17., 22., 13.])

# %%
#data['critic_score'] = pd.to_numeric(data['critic_score'], errors='ignore').astype('Int64')

# %%
data['year_of_release'] = pd.to_numeric(data['year_of_release'], errors='ignore').astype('Int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  Int64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: Int64(1), float64(6), object(4)
# memory usage: 1.4+ MB

# %%
data.duplicated(subset=['critic_score','user_score', 'rating']).value_counts()
# Out:
# True     11970
# False     4745
# dtype: int64

# %%
dub = data.loc[data.duplicated(subset=['critic_score','user_score', 'rating'])].pivot_table(index
            =['platform', 'name'], values='year_of_release')
dub.head(10)
# Out:
#                              year_of_release
# platform name
# 2600     Action Force                 1982.0
#          Adventures of Tron           1981.0
#          Air Raid                     1981.0
#          Airlock                      1981.0
#          Alien                        1981.0
#          Alien's Return               1982.0
#          Armor Ambush                 1981.0
#          Assault                      1982.0
#          Asteroids                    1980.0
#          Astroblast                   1981.0

# %%
dub = dub.reset_index(inplace=False)
dub['year_of_release'].value_counts()
# Out:
# 2009.0    1029
# 2008.0    1011
# 2010.0     924
# 2011.0     800
# 2007.0     768
# 2006.0     683
# 2005.0     586
# 2002.0     559
# 2003.0     496
# 2004.0     465
# 2012.0     435
# 2015.0     430
# 2014.0     383
# 2016.0     362
# 1998.0     357
# 2013.0     339
# 2001.0     322
# 1999.0     314
# 2000.0     278
# 1997.0     275
# 1996.0     258
# 1995.0     219
# 1994.0     120
# 1993.0      60
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1983.0      17
# 1989.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1984.0      14
# 1985.0      12
# 1980.0       9
# 2008.5       1
# Name: year_of_release, dtype: Int64

# %%
dub['platform'].value_counts()
# Out:
# DS      1743
# PS2     1338
# PS      1075
# PSP      951
# Wii      892
# PS3      715
# GBA      637
# PC       604
# X360     600
# XB       498
# 3DS      411
# PSV      368
# GC       356
# N64      316
# SNES     239
# PS4      231
# SAT      173
# XOne     129
# 2600     116
# GB        97
# NES       97
# WiiU      86
# DC        47
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: platform, dtype: int64

# %%
dub['name'].value_counts().head(15)
# Out:
# Need for Speed: Most Wanted                                           8
# FIFA 12                                                               7
# The Amazing Spider-Man 2 (2014)                                       7
# Sonic & All-Stars Racing Transformed                                  6
# Ratatouille                                                           6
# Disney Infinity 2.0: Marvel Super Heroes                              6
# Cars 2                                                                6
# Rapala Pro Bass Fishing 2010                                          6
# FIFA Soccer 07                                                        6
# The Walking Dead: Season One                                          6
# The Amazing Spider-Man (Console Version)                              6
# Transformers: Revenge of the Fallen (XBox 360, PS3, & PC Versions)    6
# Adventure Time: Finn & Jake Investigations                            6
# ...

# %%
dub.query('name == "Need for Speed: Most Wanted"')
# Out:
#       platform                         name  year_of_release
# 2790       GBA  Need for Speed: Most Wanted           2005.0
# 3259        GC  Need for Speed: Most Wanted           2005.0
# 4182        PC  Need for Speed: Most Wanted           2008.5
# 7260       PS3  Need for Speed: Most Wanted           2012.0
# 8991       PSV  Need for Speed: Most Wanted           2012.0
# 10509     WiiU  Need for Speed: Most Wanted           2013.0
# 10889     X360  Need for Speed: Most Wanted           2005.0
# 11431       XB  Need for Speed: Most Wanted           2005.0

# %% [markdown]
# Игра Need for Speed: Most Wanted была выпущена в 2012 году, ни 2008, ни тем более 2005 года там быть не может.
#
# !Но я не понимаю как мне выборочно по двум условиям их удалить, при этом не удалить все данные в датафрейме, поскольку в случае с срезом или запросом я обращаюсь именно по этой конкретной игре, а все остальные данные просто улетают. В любом случае учусь и стремлюсь к наиболее грамотному исполнению своей работы!

# %%
data[['name', 'platform']].duplicated().sum()
data.loc[data[['name', 'platform']].duplicated()]
# Out:
#                               name platform  year_of_release     genre  \
# 1591   Need for Speed: Most Wanted     X360             2005    Racing
# 4127            Sonic the Hedgehog      PS3             <NA>  Platform
# 11715  Need for Speed: Most Wanted       PC             2012    Racing
# 14244                          NaN      GEN             1993       NaN
# 16230                Madden NFL 13      PS3             2012    Sports
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 1591        1.0      0.13      0.02         0.10          83.0         8.5
# 4127        0.0      0.48      0.00         0.00          43.0         4.1
# 11715       0.0      0.06      0.00         0.02          82.0         8.5
# 14244       0.0      0.00      0.03         0.00           NaN         NaN
# 16230       0.0      0.01      0.00         0.00          83.0         5.5
#
#       rating
# 1591       T
# 4127    E10+
# 11715      T
# 14244    NaN
# 16230      E

# %%
data[['name', 'platform']].duplicated().sum()
data.loc[data[['name', 'platform']].duplicated()]
data.loc[data[['name', 'platform']].duplicated()] = data[['name', 'platform']].drop_duplicates().dropna()
data.loc[data[['name', 'platform']].duplicated()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 4127   NaN      NaN             <NA>   NaN       NaN       NaN       NaN
# 11715  NaN      NaN             <NA>   NaN       NaN       NaN       NaN
# 14244  NaN      NaN             <NA>   NaN       NaN       NaN       NaN
# 16230  NaN      NaN             <NA>   NaN       NaN       NaN       NaN
#
#        other_sales  critic_score  user_score rating
# 4127           NaN           NaN         NaN    NaN
# 11715          NaN           NaN         NaN    NaN
# 14244          NaN           NaN         NaN    NaN
# 16230          NaN           NaN         NaN    NaN

# %% [markdown]
# Дело сделано!

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №5__
#
# Отлично, неявные дубликаты найдены!)

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
# Логика корректна, но не до конца. Рекомендую проверить столбец name, год релиза и платформу

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №3__
#
#  Стоит посмотреть, есть ли в данных дубликаты, у которых отличаются только некоторые столбцы (name, год релиза и платформу). Такие строки мы можем удалить, если их немного (в абсолютных значениях и относительно общего количества данных). Такие строки будут с большой вероятностью настоящими дубликатами (у них будут совпадать и названия, и местоположения, и количество мест..), а появляться они могут в случаях, когда данные собирались из разных источников и/или в системе были какие-то сбои при логировании.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №4__
#
#
# Попробуй, например, использовать вот так год для нахождения неявных дубликатов:
#
#     df[['name', 'platform']].duplicated().sum()

# %% [markdown]
# Судя по всему строк, в которых вообще нет никаких оценок и рейтинга целых 11970, в остальных случаях нет той или иной оценки или рейтинга. Почти 70 % игр не имеют оценок вовсе, этот очень значимая часть. Часть проектов без оценок вовсе относятся к популярным тот же Super Mario, Need for Speed, FIFA 12. Невозможно назвать подобные игры непопулярными и обделенными оценками и рейтингом. Встречаются такие пропуски на практически всех популярных платформах и за каждый год. В данном случае могу сказать, что скорее всего пропуски связаны с ошибкой при выгрузке данных или недобросовестной работой, человека проводившего эту выгрузку. Поскольку эти пропуски не имеют четкой связи и у не имеют выборочного характера.

# %%
data.isna().sum()
# Out:
# name                  6
# platform              5
# year_of_release     273
# genre                 6
# na_sales              5
# eu_sales              5
# jp_sales              5
# other_sales           5
# critic_score       8582
# user_score         9129
# rating             6770
# dtype: int64

# %% [markdown]
# Пропуски с именем стоит убрать, поскольку принадлежность такого продукта к чему-либо нельзя определить, нет имени. Пропуск в колонке с жанром не критичен, но можно и убрать. Пропуски есть в колонке с годом релиза, мы не можем точно знать год выпуска конкретных продуктов, поэтому лучше не трогать эти пропуски и не терять эти игры. Большинство же пропусков сосредоточено в колонках с оценками критиков, пользователей и с рейтингом. Во первых пропусков слишком много, чтобы бездумно их убирать, во вторых игра могла оказаться непопулярной, а потому отзывов могло и не быть вовсе или на ресурсе, из которого были получены эти данные просто не было оценок данного проекта или к примеру отзывы от пользователй есть, а оценку критиков проект не пока получил.

# %%
data = data.dropna(subset=['name'])
data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release     268
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         9123
# rating             6764
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Строки с пропусками в Name лучше удалить. Мы почти ничего не знаем об этих играх.

# %%
data['total_sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales']
data['total_sales'].head()
# Out:
# 0    74.09
# 1    39.47
# 2    32.23
# 3    29.82
# 4    30.38
# Name: total_sales, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Можно еще вот так:
#
#     df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)
#
# </div>

# %%
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN    NaN
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 4      8.89     10.22         1.00           NaN         NaN    NaN
#
#    total_sales
# 0        74.09
# 1        39.47
# 2        32.23
# 3        29.82
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16709 entries, 0 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16709 non-null  object
#  1   platform         16709 non-null  object
#  2   year_of_release  16441 non-null  Int64
#  3   genre            16709 non-null  object
#  4   na_sales         16709 non-null  float64
#  5   eu_sales         16709 non-null  float64
#  6   jp_sales         16709 non-null  float64
#  7   other_sales      16709 non-null  float64
#  8   critic_score     8133 non-null   float64
#  9   user_score       7586 non-null   float64
#  10  rating           9945 non-null   object
#  11  total_sales      16709 non-null  float64
# dtypes: Int64(1), float64(7), object(4)
# memory usage: 1.7+ MB

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Важным пунктом на этом этапе является проверка "неявных" дубликатов. Неявные дубликаты могут появиться в случаях, когда данные собирались из разных источников или в системе были какие-то сбои при логировании.
#
# Проверку на такие дубликаты можно сделать с помощью https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html, передав в параметр subset список названий колонок.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Как думаешь, почему могли возникнуть все эти пропуски?

# %% [markdown]
# ### 3

# %%
data['year_of_release'].value_counts().sort_values(ascending=True).plot(kind='barh', figsize
                                            =(12,10), grid=False, rot=8).set_title('Кол-во выпущенных игр по годам', fontsize
                                                                           =14, color='Black')
# Out:
# Text(0.5, 1.0, 'Кол-во выпущенных игр по годам')

# %% [markdown]
# Как видно из графика все 80-ые года количество выпускаемых игр практически не менялось, находясь в промежутке от 9, до 46 игр в год, в связи с низкой актуальностью игровой индустрии в эти годы. Первые сигналы роста начинаются с 1991 года, возможно, благодаря тетрису. В 2000 году палвный рост сменяется стремительным, к 2002 было выпущено около 800 игровых продуктов. Рост продолжается, а пиковыми значения для игровой индустрии при ходятся на 2008 и 2009 годы, когда в год игр выпускалось немногим более 1400. С 2010 года начинается стремительное снижение, после достижения минимума 2013 года в 544 игры, после происходит постепенный рост и новое падение в 2016 году, до 502 игр.

# %% [markdown]
# Понимаю, что горизонтальная столбчатая диаграмма для визуализации этих данных не подходит, переделал на линейный график ниже.

# %%
year = data.pivot_table(index='year_of_release', values='na_sales', aggfunc=['count'])
year['year_r'] = year.index
year.plot(y='count', x='year_r', style='o-g', figsize=(13, 6)).set_title('Кол-во выпущенных игр по годам', fontsize
                                                                           =14, color='Black')
plt.gca().set(xlabel='Год выпуска', ylabel='Число продаж')
year.tail(10)
# Out:
#                    count year_r
#                 na_sales
# year_of_release
# 2007                1197   2007
# 2008                1427   2008
# 2009                1426   2009
# 2010                1255   2010
# 2011                1136   2011
# 2012                 651   2012
# 2013                 544   2013
# 2014                 581   2014
# 2015                 606   2015
# 2016                 502   2016

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отличная визуализация. При желании можно немного улучшить. Смотри: Для того, чтобы построить графить, нужно сгруппировать данные (в нашем случае год релиза и колличество)
#
# ![image.png](attachment:image.png)
#
# ---
# А потом с помощью библиотеки sns (она мощная, и с ней можно делать всё, что угодно). По данным сгруппированной таблицы строим график. При желании забирай себе =) Главное поиграйся с аргументами и разберись. В дальнейших проектах вы будете строить мощные графики, там пригодится такой навык
#
# ![image-2.png](attachment:image-2.png)
# </div>

# %% [markdown]
# Суда по графику большинство выпущенных игр нахлдятся в промежутке с 2000 по 2016 годы, поэтому целесообразнее рассматривать именно этот период. Но игровая индустрия за эти годы стремительно менялась, многие продукты устаревали, аудитория постоянно переключалась на новые релизы, менялись стандартны, стремительно развивались движки и технологии, поэтому наиболее актуальные данные для исследования находятся на промежутке с 2012 по 2016 год

# %%
platforms = data.pivot_table(index=['platform'], values=['total_sales'], aggfunc=['sum'])
platforms.columns = ['summary_sales']
platforms = platforms.sort_values(by='summary_sales', ascending=False)
platforms.head()
# Out:
#           summary_sales
# platform
# PS2             1062.33
# X360             884.51
# Wii              828.44
# PS3              803.48
# DS               746.86

# %%
platform_by_year = data.pivot_table(index=['platform', 'year_of_release'], values=['total_sales'], aggfunc=['sum'])
platform_by_year.columns = ['summary_sales']
platform_by_year_a = platform_by_year
platform_by_year = platform_by_year.reset_index(inplace=False)
platform_by_year.tail()
platform_with_names = data.pivot_table(index=['platform', 'year_of_release', 'name'], values=['total_sales'], aggfunc=['sum'])
platform_with_names.columns = ['summary_sales']
platform_with_names = platform_with_names.reset_index(inplace=False)
platform_by_year.query('year_of_release >= 2016')
platform_with_names = platform_with_names.query('year_of_release >= 2013')

# %%
data = data.query('year_of_release >= 2013')

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Тут согласен

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Неиспользуемый код лучше удалить

# %%
ps4 = platform_by_year.query('platform == "PS4"')
pc = platform_by_year.query('(platform == "PC") and (year_of_release >= 2013)')
xone = platform_by_year.query('platform == "XOne"')
fig, ax = plt.subplots(1, 3, figsize=(15,4), dpi=80)
plt.suptitle('Изменение продаж в млн копий топовых игровых платформ по годам', fontsize=13)
ax[0].plot(ps4['year_of_release'], ps4['summary_sales'],'o-',color='midnightblue')
ax[0].set_title('PS4')
ax[1].plot(pc['year_of_release'], pc['summary_sales'],'o-',color='orange')
ax[1].set_title('PC')
ax[2].plot(xone['year_of_release'], xone['summary_sales'],'o-',color='darkgreen')
ax[2].set_title('XOne')
# Out:
# Text(0.5, 1.0, 'XOne')

# %% [markdown]
#  Как видно из построенных мной графиков изменения продаж в млн $ среди топовых игровых платформ, большинство из платформ с лучшими продажами потеряли свои былые обьемы еще до 2013 года, а некоторые намного раньше.
#
#  Относительно многих уже устаревших платформ(предыдущие поколения PS, PS2, PS3) довольно свежо выглядит именно PS4, первые продажи игр для этой платформы стартовали в 2013 году, что нам подходит и даже в период общего спада обьемов продаж в 2015-2016 года, продажи остаются довольно высокими. Стоит отметить, что судя по другим специализитрованным игровым платформам цикл от старта продаж, до их полного падения составляет 8-10 лет. Значит PS4 не растеряет совю популярность в ближайшие годы.
#
#  Ситуация выглядит неплохо у PC. Игры на PC(персональный компьютер) выходят с далеких восьмидесятых, а число пользователй ПК в мире экспоненциально возрастает, поэтому всё же стоит сдлелать ставку на ПК, в особенности на игровые ключи, поскольку дисководы в месте с дисками теряют свою актульность на данной платформе.
#
#  Чуть хуже, но тоже неплохо дела обстоят у XOne, продажи 16 года хуже чем у PS4, но и обьемы годовые обьемы обычно в два раза меньше. Также важно учесть, что XOne на данный момент имееет несколько модификаций(базовая 13 года и S версия 16 года), новейшая модификация XOne X ожидается как раз в 2017, это однозначно поднимет уровень продаж на платформе. Поэтому рекомендую сделать ставку на XOne.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# __Комментарий от ревьюера №1__
#
# Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже брать не стоит
# </div>

# %% [markdown]
# А я и не брал длинные интервалы, мне было важно понять какие платформы своё отжили, а у каких есть потенциал

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
#
# Давай попробуем разложить наши мысли по полочкам.
#
# * Игровая индустрия меняется очень быстро. Если ты взял данные например с 1985 года, это означает, что у тебя есть информация о том, какие игры были популярны ещё во времена PlayStation и Xbox 360. Согласись, это было очень давно! С тех пор появилось множество новых платформ, жанров, технологий и мировых тенденций, которые сильно изменили игровую индустрию.
#
# * Как и в любом другом бизнесе, в игровой индустрии есть тренды, которые приходят и уходят. Если учесть данные за все года, ты рискуешь учитывать в своем анализе тренды, которые уже ушли в прошлое. Это может исказить твое понимание текущей ситуации и не дать верного направления для будущего.
# * Хотя в мире данных большой объем информации часто считается преимуществом, в этом контексте это может стать минусом. Анализируя такой большой временной промежуток, ты можешь упустить мелкие, но важные детали, которые будут актуальны для более короткого периода.
#
# 2016 год: Ты уже заметил, что данные за 2016 год не полные. Это ещё один повод сделать акцент на более поздних годах. Если ты начнешь анализ с 12/13 или 14 года, ты будешь иметь более свежий и точный контекст.
#
# В общем, я бы рекомендовал отсечь данные до 2013 или 2014 года. Так ты сможешь сосредоточиться на актуальных трендах и дать наиболее верные рекомендации для будущего. Надеюсь, теперь смысл этого выбора стал понятнее!
#
# ---
#
# И далее проводить EDA и гипотезы по данным актуального периода

# %%
ps4_g = platform_with_names.query('platform == "PS4"')
xone_g = platform_with_names.query('platform == "XOne"')
pc_g  = platform_with_names.query('(platform == "PC") and (year_of_release >= 2013)')
c = ['darkblue', 'darkgreen', 'orange'] 
sales = [ps4_g['summary_sales'], xone_g['summary_sales'], pc_g.query('year_of_release >= 2013')['summary_sales']]   
fig = plt.figure(figsize=(9, 6))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(sales, sym='k+', patch_artist=True)
ax.set_xticklabels(['PS4', 'XOne', 'PC'])
plt.suptitle('Межквантильный размах в продажах игр между платформами', fontsize=14)
for patch, color in zip(bp['boxes'], c):
    patch.set_facecolor(color)
plt.gca().set(xlabel='Платформы', ylabel='Продажи в млн копий')
plt.ylim(0,2)
plt.show()
print('Медиана PS4', ps4_g['summary_sales'].median(), ', медиана XOne',xone_g['summary_sales'].median(), ', медиана PC', pc_g['summary_sales'].median())
# Out:
# Медиана PS4 0.17 , медиана XOne 0.2 , медиана PC 0.07

# %% [markdown]
# Лучший диапазон нормальных значений в продажах у XOne, медианные продажи тоже высокие 200 тыс копий, есть и выбросы за пределами области нормальных значений, вплоть до 7 млн проданных копий игр. Немного отстает PS4, c медианой в 170 тыс копий, и крайне схожей областью нормальных значений, однако диаграмма размаха PS4 имеет важно свойство, связанное с выбросами. Количество выбросов у PS4 значительно больше чем у XOne, это важный параметр, поскольку и в 2017 году мы можем ожидать больше продуктов с не ординарно большими продажами на PS4, относительно разумеется области нормальных значений. У PC за последние 4 года дела обстоят не очень, медиана всего 70 тыс копий, а область нормальных значений ограничена велличиной в примерно 300 тыс продаж, но как я уже и говорил, платформа остается актульной и обязательно будет показывать свои стабильные, хоть и не высокие в нынешней коньюнктуре рынка продажи.

# %% [markdown]
# Я конечно гениально поступил, когда начал оценивать диаграмму размаха по четырем значения с каждого года нечего сказать)

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
# В переменной ps4 ты считаешь сумму продаж за каждый год, а нам нужно реализовать на боксплоте все данные (т.е. распределение продаж каждой игры)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Всё верно

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Лучше после каждого раздела, графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи - так проще читать проект, поскольку будущим коллегам или заказчику не надо будет самим интерпретировать результаты каждого раздела, теста или графика.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Корректнее реализовать на одном графике

# %%
dps4=data.query('platform == "PS4"')
dps4.plot(kind='scatter', y='total_sales', x='user_score', color
          ='midnightblue', alpha=0.4, figsize
          =(8, 6)).set_title('Зависимость обьема продаж игр для PS4 от пользовательских оценок игр', fontsize=14)
plt.gca().set(xlabel='Оценки пользователей', ylabel='Продажи в млн $')
dps4['user_score'].corr(dps4['total_sales'])
# Out:
# -0.03126053686666919

# %%
dps4.plot(kind='scatter', y='total_sales', x='critic_score', color
          ='midnightblue', alpha=0.4, figsize
          =(8, 6)).set_title('Зависимость обьема продаж игр для PS4 от оценок критиками игр', fontsize=14)
plt.gca().set(xlabel='Оценки критиков', ylabel='Продажи в млн $')
dps4['critic_score'].corr(dps4['total_sales'])
# Out:
# 0.4058867746520127

# %%
dxone=data.query('platform == "XOne"')
dxone.plot(kind='scatter', y='total_sales', x='user_score', color
           ='green', alpha=0.4, figsize
           =(8, 6)).set_title('Зависимость обьема продаж игр для XOne от пользовательских оценок игр', fontsize=14)
plt.gca().set(xlabel='Оценки пользователей', ylabel='Продажи в млн $')
dxone['user_score'].corr(dxone['total_sales'])
# Out:
# -0.06880394425598692

# %%
dxone.plot(kind='scatter', y='total_sales', x='critic_score', color
           ='green', alpha=0.4, figsize
           =(8, 6)).set_title('Зависимость обьема продаж игр для PS4 от оценок критиками игр', fontsize=14)
plt.gca().set(xlabel='Оценки критиков', ylabel='Продажи в млн $')
dxone['critic_score'].corr(dxone['total_sales'])
# Out:
# 0.41720638309101765

# %%
dpc=data.query('platform == "PC"')
dpc.plot(kind='scatter', y='total_sales', x='user_score', color
           ='orange', alpha=0.4, figsize
           =(8, 6)).set_title('Зависимость обьема продаж игр для PC от пользовательских оценок игр', fontsize=14)
plt.gca().set(xlabel='Оценки пользователей', ylabel='Продажи в млн $')
dpc['user_score'].corr(dpc['total_sales'])
# Out:
# -0.09175209083674118

# %%
dpc.plot(kind='scatter', y='total_sales', x='critic_score', color
           ='orange', alpha=0.4, figsize
           =(8, 6)).set_title('Зависимость обьема продаж игр для PC от оценок критиками игр', fontsize=14)
plt.gca().set(xlabel='Оценки критиков', ylabel='Продажи в млн $')
dpc['critic_score'].corr(dpc['total_sales'])
# Out:
# 0.19693097479003824

# %% [markdown]
# По итогам построенных мной корреляций выяснилось, что на всех трех обозначенных мной платформах(PS4, XOne, PC), как актульные сложилась примерно одна и та же картина. Коэффициент корреляций Пирсона на графиках оценок пользователей и продаж близок к нулю на всех трёх платформах, это значит, что какой-то прочной зависимости между этими данными нет, т.е оценки пользователей не влияют на продажи. Иная ситуация скалдывается у корреляции оценок критиков и продаж, где коэффициент больше нуля, в случае с PS4 и XOne он равен 0.4, в случае с PC же 0.25. Но в любом случае такую связь можно обозначить как слабую, но она есть. Логичным будет сделать вывод, что на продажи скорее влияет мнение критиков, а не пользователей.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Графики отличные. Верная интерпритация значений корреляции Пирсона. Ты молодец =)
# </div>

# %%
data['genre'].unique()
agregate_genre = data.query('((platform == "PC") or (platform == "PS4") or (platform == "XOne")) and (year_of_release >= 2013)').pivot_table(index
        =['genre'], values='total_sales', aggfunc='sum')
agregate_genre = agregate_genre.reset_index(inplace=False)
agregate_genre
# Out:
#            genre  total_sales
# 0         Action       122.20
# 1      Adventure         8.36
# 2       Fighting         9.62
# 3           Misc        14.34
# 4       Platform         7.46
# 5         Puzzle         0.02
# 6         Racing        20.22
# 7   Role-Playing        38.96
# 8        Shooter       138.50
# 9     Simulation         9.19
# 10        Sports        72.94
# 11      Strategy         5.50

# %%
agregate_genre = agregate_genre.query('total_sales > 10')
fig, ax = plt.subplots(figsize=(12, 12))
ax.pie(agregate_genre['total_sales'], labels=agregate_genre['genre'], autopct='%.1f%%',
       wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
       textprops={'size': 'x-large'})
plt.suptitle('Продажи игр по жанрам на платформах PS4, XOne, PC', fontsize=22)
# Out:
# Text(0.5, 0.98, 'Продажи игр по жанрам на платформах PS4, XOne, PC')

# %% [markdown]
# Лидируют по продажам шутеры, они и впрямь были популярны во все времена и остаются таковыми по сей день на самых современных платформах, их доля от общих продаж составляет 34 % практически треть, скорее всего эти позиции не будут сданы в будущем. Следом идут игры жанра экшен - 30 %, они были и остаются на волне, вепереди этот жанр ждет множество релизов, на продукты этого жанра нужно обязательно делать ставку, поскольку он крайне популярен на консольных платформах типа PS и XBox. Следом идут игры спортивного жанра 18 %, в особенности эта популярность обуспечена серией игр FIFA. Немногим уступают игры жанра РПГ - 9.6 %, остаются популярными и по сей день, жанр актуальный и имеет пространства для экспериментов, тоже следует обратить внимание при подготовке пула приоритетной продукции. Уже значительно меньше у симуляторов - 8 % от общих продаж, про этот  жанр не стоит забывать игры симуляторы охватывают всё большие сферы нашей жизни и могут дать этому рынку новые симуляции. А вот хуже всего обстоят дела с играми жанра гонки - 5 %, misc - 3.5 %, популярный в прошлом жанр, среди игр этого жанра есть популярные серии, поэтому лучше сконцентрироваться на них, а не на всем жанре.
#
# На график не попали такие жанры как платформеры, файтинги, пазлы, симуляторы и приключения ввиду низких продаж на представленных мной платформах.
#
# Я рассматривал популярность тех или иных жанров только на платформах, которые отнес к актульным, за актуальный период.

# %%
agr_gen = data.query('((platform == "PS4") or (platform == "XOne") or (platform == "PC")) and (year_of_release >= 2013)')
agr_gen = agr_gen.pivot_table(index='genre', values='total_sales', aggfunc=['median', 'mean'])
agr_gen.columns = ['median_value', 'mean_value']
agr_gen.sort_values(by='median_value', ascending=False)
# Out:
#               median_value  mean_value
# genre
# Shooter               0.51    1.247748
# Sports                0.26    0.751959
# Role-Playing          0.17    0.469398
# Misc                  0.16    0.333488
# Platform              0.15    0.392632
# Fighting              0.14    0.356296
# Action                0.12    0.437993
# Simulation            0.10    0.296452
# Racing                0.09    0.367636
# Strategy              0.08    0.189655
# Adventure             0.06    0.157736
# Puzzle                0.02    0.020000

# %%
agr_gen['median_value'].sort_values(ascending=True).plot(kind
            ='barh', rot=-4, figsize=(11, 9), grid
            =False).set_title('Медианная величина продаж по жанрам', fontsize=20)
plt.gca().set(xlabel='Продажи в млн копий', ylabel='Жанр')
# Out:
# [Text(0.5, 0, 'Продажи в млн копий'), Text(0, 0.5, 'Жанр')]

# %% [markdown]
# Лидируют игры жанра шутер, судя по распредлелению продаж, самые высокие медианные продажи именно у этого жанра - 510 тыс копий, за ним следует жанр спорт с 260 тыс. Медианными значениями, превышающими 150 тыс копий обладают жанры: платформер, файтинг, РПГ, гонки и экшен. Менее 100 тыс копий имеют жанры типа симуляторы, пазлы, misc, стратегии и приключения. Данные медианные показатели означают, что игровые продукты с этим жанром обычно достигают уровня продаж в соответсвии с этим графиком, поэтому примерно такие ожадания можно иметь, при выходе очередного прокта в свет. По хорошему можно поделать т-тесты с проверкой гипотез, больше ли продажи конкретного жанра чем найденная медиана или построить распределение с вероятностью попадения медианы в заданный интеравал.

# %%
agr_gen['mean_value'].sort_values(ascending=True).plot(kind='barh', rot
                =-4, figsize=(11, 9), grid
                =False, color='darkgreen').set_title('Средне-арифметическая величина продаж по жанрам', fontsize=20)
plt.gca().set(xlabel='Продажи в млн копий', ylabel='Жанр')
# Out:
# [Text(0.5, 0, 'Продажи в млн копий'), Text(0, 0.5, 'Жанр')]

# %% [markdown]
# Наибольшим средним арифметическим по продажам снова обладают  шутеры - 1.24 млн копий. Следом снова идёт спорт, поэтому по ним остается тот же прогноз, что и в распределении по медианам. В этот раз более существеные показатели у РПГ - 470 тыс, возможно за счет сдвига из-за продуктов с большими продажами. Продажами более 400 тыс копий обладают гонки, платформеры, файтинги и экшен. Список так называемых аутсайдеров остаётся прежним: симуляторы, пазлы, misc, стратегии и приключения. В случае с ср арифм лидерами остаются одни и те же платформы, поэтому проекты этих жанров за частую и будут иметь кассовый успех у аудитории.

# %%
control = data.query('((platform == "PS4") or (platform == "XOne") or (platform == "PC")) and (year_of_release >= 2013)')
plt.figure(figsize=(15, 6))
(sns.boxplot(data = control, y = 'total_sales', x='genre')
    .set(title = 'Продажи по жанрам среди PS4, XOne и PC c 2013 по 2016 год', xlabel
         = 'Жанры', ylabel = 'Общие продажи', ylim=(0, 4)))
plt.show()
# а ларчик просто открывался

# %% [markdown]
#  Результаты отражаются и на диаграмме размаха среди продаж по жанрам, медианы прижаты к оси абсцисс и близки к нулю. В этот раз представлены жанры с лучшими продажами, за актуальный период. Наилучшая область нормальных значений и самый большой диапазон между квантилями у шутеров, медианные продажи составляют 510 тыс копий, также пристутсвует множество выбросов, область нормальных значений тоже велика, её конечная граница больше 3.5 млн копий, что является очень большим показателем и внушает уверенность в будущих крупных обьемах продаж.
#
#  У игр жанра спорт область нормальных значений значительно больше чем у платформеров, верхняя граница на уровне 1.8 млн копий, медианные продажи ранвы 260 тыс копий, очень хорошие показатели в целом, пристутсвует много выбросов, т.е продаж с еще более высокими показателями, можно смело заявить, что жанр пользуется популярностью и будет отлично продаваться.
#
#  У РПГ медиана составила 170 тыс копий, что является хорошим результатом, область нормальных значений своей верхненй границей немного превышает 1 миллион, что тоже гуд, выбросы присутствуют. Жанр пользуется популярностью, остается релевантным и будет хорошо продаваться и дальше.
#
#  Интересно складывается ситуация с жанром экшен. Да медиана всего 120 тыс копий, нормальные значения обычно немногим меньше 1 миллиона проданных копий. Но есть преимущество относительно прочих жанров, самое большое кол-во выбросов приходится именно на, поэтому есть довольно высокие шансы, что проекты в 2017 году будут превосходить ожидания и показывать неожиданно высокие продажи. Важно учесть, только в случае появления проектов, которые оценит аудитория, есть такие шансы, что у экшенов не будет громких релизов и вовсе, поэтому важно следить за новинками тех же популярных серий ир в этом жанре, потому что судя по общим объемам продаж и медиане, было выпущено очень много экшенов с низкими продажами.
#
#  Файтинги обладают очень малым диапазоном нормальных значений, выбросов мало, медиана составляет 140 тыс копий, судя по всему больших результатов от файтингов ожидать не стоит. Ожидания насчет файтингов низкие, в связи с низким обьемом продаж в последние годы.
#
#  Относительно неплохо дела обстоят у игр жанра misc, довльно высокая медиана 160 тыс, очень шировакя область нормальных значений свыше 500 тыс копий. Выбросов не много. Поэтому у меня есть хорошие ожидания по поводу этого жанра, а конкретно среди наиболее популярных будущих релизов серий игр.
#
#   Неплохие медианные продажи также у платформеров - 150 тыс копий, да область нормальных значений мала, до 400 тыс проданных игр, однако с такимми медианными показателями можно ожидать стабильные продажи. При этом рекомендую с осторожностью относится к предложениям игрс типа платформер, поскольку объемы продаж у платформеров за последние годы довольно низкие. Привыборе между платформерами и misc, поскольку в среднем этот жанр продавался лучше.
#
#  У игр с жанром гонки медианные продажи составляют  всего 90 тыс копий, что маловато, область нормальных значений не превышает 500 тыс копий, но есть и плюсы, у гонок довольно много выбросов близких к области нормальых значений. Это значит, что всё же можно ожидать позитива от их в следующем году.
#
#  Поэтому основными фаворитами являются шутеры, спорт, экшен и РПГ. Именно эти жанры по моему мнению будут наиболее доходными для компании в непростые времена.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №4__
#
# Верно, шутер в лидерах

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# __Комментарий от ревьюера №2__
#
# А для чего делать срез по каждому жанру?
#
# ---
#
# Также сейчас у тебя не видны квантили и медианы, что не даёт возможности определить, какой жанр прибыльнее

# %%
plt.figure(figsize=(13, 8))
(sns.boxplot(data = data, y = 'total_sales', x='genre')
    .set(title = 'Продажи по жанрам за 2014-2016 гг', xlabel = 'Платформы', ylabel = 'Общие продажи', ylim=(0, 3)))

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# __Комментарий от ревьюера №3__
#
# Выше показал премер, посмотри, пожалуйста

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# __Комментарий от ревьюера №3__
#
# А для чего делать срез по каждому жанру?
#
# ---
#
# Также сейчас у тебя не видны квантили и медианы, что не даёт возможности определить, какой жанр прибыльнее

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# __Комментарий от ревьюера №1__
#
# Твои расчеты нужно еще немного дополнить. Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние или медианные продажи
#
# ---
#
# Давай тут ещё посмотрим на распределение с помощью боксплота?
#
# ---
#
# PS. Тут нужно рассмотреть продажи по всем платформам, ан е только актуальным
# </div>

# %% [markdown]
# ### 4

# %% [markdown]
# В северо-американском регионе за всю историю оказалась наиболее популярными продукты для приставки X360 от Microsoft. Второе место у PS2 от японской Play Station. Третье место по продажам у Wii, это крайне популярная японская приставка от Nintendo. Четвертое место у более современного поколения приставок PS3. Пятое место у DS тоже от Nintendo, но в этот раз уже карманная консоль, а не портативная.
#
# Как мы видим на американском рынке были и до сих пор остаются популярными игры предназанченные для японских игровых платформ.

# %%
NA_plat = data.pivot_table(index=['platform'], values='na_sales', aggfunc='sum')
NA_plat = NA_plat.sort_values(by='na_sales', ascending=False).head()
NA_plat.plot(kind='barh', figsize=(6, 5), grid=False, color
              ='darkblue').set_title('Топ пять самых популярных платформ в америке', fontsize=14)
plt.gca().set(xlabel='Продажи в млн копий', ylabel='Платформа')
NA_plat
# Out:
#           na_sales
# platform
# PS4         108.74
# XOne         93.12
# X360         81.66
# PS3          63.50
# 3DS          38.20

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# __Комментарий от ревьюера №1__
#
# Давай визуализируем полученные данные в этом разделе?

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# __Комментарий от ревьюера №2__
#
# Отсутствуют правки. Ошибка при выгрузке?

# %% [markdown]
# В европейском регионе объему продаж традиционно меньше. Лидеры PS2 и PS3. Третье место занимет лидер мариканского рынка X360. Следом идут продажи на Wii. Пятое место занимает первое - легендарное поколение PS.

# %%
EU_plat = data.pivot_table(index=['platform'], values='eu_sales', aggfunc='sum')
EU_plat = EU_plat.sort_values(by='eu_sales', ascending=False).head()
EU_plat.plot(kind='barh', figsize=(6, 5), grid=False, color
              ='teal').set_title('Топ пять самых популярных платформ в европе', fontsize=14)
plt.gca().set(xlabel='Продажи в млн копий', ylabel='Платформа')
EU_plat
# Out:
#           eu_sales
# platform
# PS4         141.09
# PS3          67.81
# XOne         51.59
# X360         42.52
# 3DS          30.96

# %% [markdown]
# Рынок Японии самый маленький по охватам, но с учетом кол-ва населения остается не менее важным для компании. На нем лидируют преимущественно продукты для японских платворм: DS, PS, PS2, SNES и 3DS. Поэтому на японском рынке следует обращать внимание на игры для платформ от Play Station и Nintendo.

# %%
JP_plat = data.pivot_table(index=['platform'], values='jp_sales', aggfunc='sum')
JP_plat = JP_plat.sort_values(by='jp_sales', ascending=False).head()
JP_plat.plot(kind='barh', figsize=(6, 5), grid=False, color
              ='darkred').set_title('Топ пять самых популярных платформ в европе', fontsize=14)
plt.gca().set(xlabel='Продажи в млн копий', ylabel='Платформа')
JP_plat
# Out:
#           jp_sales
# platform
# 3DS          67.81
# PS3          23.35
# PSV          18.59
# PS4          15.96
# WiiU         10.88

# %% [markdown]
# Самым популярным жанром в американском регионе является экшен, и он остается одним из лидеров по продажам среди самых современных платформ. Второе место у жанра спорт, здесь прослеживается дивергенция, поскольку спорт всё еще популярен, но всё же далек от высоких продаж игры жанра экшен на приставках PS4, XOne и PC. Третье место у шутров, сейчас у них самые высокие охваты, поэтому в первую очередь на них и игры с жанром экшен следует обратить внимание компании. Со схожими продажами на четвертом и пятом месте рамположились платформеры и misc, да продажи большие, но сейчас это совсем не так и на современных платформах эти жанры аутсайдеры, но для покорения американского рынка лучше не обделять вниманием платформеры. На игры жанра misc делать ставку не рекомендутся, а если и следует, то только на уже зарекомендовавшие себя, популярные серии игр.

# %%
NA_genre = data.pivot_table(index='genre', values='na_sales', aggfunc='sum')
NA_genre = NA_genre.sort_values(by='na_sales', ascending=False).head()
NA_genre.plot(kind='barh', figsize=(6, 5), grid=False, color
              ='darkblue').set_title('Топ пять самых популярных жанров в америке', fontsize=14)
plt.gca().set(xlabel='Продажи в млн копий', ylabel='Жанр')
NA_genre
# Out:
#               na_sales
# genre
# Action          126.05
# Shooter         109.74
# Sports           65.27
# Role-Playing     46.40
# Misc             27.49

# %% [markdown]
# На европейском рынке в первых трех местах ситуация абсолютно идентичная, что на американском, что подтверждает суждение об долгоиграющем характере жанров экшен и шутер. Четвертое место занимают гонки и миск. Миск стоит исключить и сферы интересов компании, а гонки имеют ряд популярпных серий игр, которые всё еще неплохо продаются, типа need for speed.

# %%
EU_genre = data.pivot_table(index='genre', values='eu_sales', aggfunc='sum')
EU_genre = EU_genre.sort_values(by='eu_sales', ascending=False).head()
EU_genre.plot(kind='barh', figsize=(6, 5), grid=False, color
              ='teal').set_title('Топ пять самых популярных жанров в европе', fontsize=14)
plt.gca().set(xlabel='Продажи в млн копий', ylabel='Жанр')
EU_genre
# Out:
#               eu_sales
# genre
# Action          118.13
# Shooter          87.86
# Sports           60.52
# Role-Playing     36.97
# Racing           20.19

# %% [markdown]
# На японском рынке сложилась кардинально другая ситуация. Перове место у РПГ, возможно за счет выскокой популярности сетевых рпг в этой стране. Этот жанр абсолютный лидер(объемы продаж в два раза больше чем у второго места с экшен играми) и для завоевания японского рынка и успешных продаж на нём будет формирование привлекательных предложений с игрыми жанра РПГ. Второе место у экшен игр, что неудивительно, экшен игры часто пересекаются по тематике с РПГ. Третье место у игр жанра спорт, а четвертое с небольшим отрывом получает жанр платформер, именно этот жанр и по сей день остается в японии достаточно популярным. И последним традиционно идет misc.

# %%
JP_genre = data.pivot_table(index='genre', values='jp_sales', aggfunc='sum')
JP_genre = JP_genre.sort_values(by='jp_sales', ascending=False).head()
JP_genre.plot(kind='barh', figsize=(6, 5), grid=False, color
              ='darkred').set_title('Топ пять самых популярных жанров в Японии', fontsize=14)
plt.gca().set(xlabel='Продажи в млн копий', ylabel='Жанр')
JP_genre
# Out:
#               jp_sales
# genre
# Role-Playing     51.04
# Action           40.49
# Misc              9.20
# Fighting          7.65
# Shooter           6.61

# %% [markdown]
# ### 5

# %% [markdown]
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#
# Используем T-тест для двух независимых выборок.
#
# H0 - пользовательские оценки на платформах XOne и PC равны.
# H1 - пользовательские оценки на платформах XOne и PC не равны.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# А почему примерно?

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Гипотезы верные. Отлично!
# </div>

# %%
dxone = dxone.dropna()
dpc = dpc.dropna()
alpha = 0.01
res_x = st.ttest_ind(dxone['user_score'], dpc['user_score'], alternative='two-sided')
if res_x.pvalue < alpha:
    print('Отвергаем', res_x.pvalue)
else:
    print('Не отвергаем', res_x.pvalue)
# Out:
# Не отвергаем 0.13155855487910809

# %% [markdown]
# Судя по всему оценки игр на заданных платформах особо не различаются. Значит вкусы пользователй этих двух, совершенно разных платформ довольно близки.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №3__
#
# Поправь, пожалуйста, вывод (Мы не отвергает Но)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №4__
#
# - Да, тут оценки пользователей и критиков одинковые.
# - Дисперсии выборок можно сравнить с помощью стат.теста Левене (https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.levene.html) или теста Барлетта (https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.bartlett.html#scipy.stats.bartlett) или просто сравнить значения вручную "на глаз".

# %% [markdown]
# Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Используем T-тест для двух независимых выборок.
#
# H0 - пользовательские оценки на платформах жанров экшен и спорт равны.
# H1 - пользовательские оценки на платформах жанров экшен и спорт не равны.

# %%
genre_ac = data.query('genre == "Action"').dropna()
genre_sp = data.query('genre == "Sports"').dropna()
res_g = st.ttest_ind(genre_ac['user_score'], genre_sp['user_score'], alternative = 'two-sided')
if res_g.pvalue < alpha:
    print('Отвергаем', res_g.pvalue)
else:
    print('Не отвергаем', res_g.pvalue)
# Out:
# Отвергаем 1.7886065917750245e-15

# %% [markdown]
# Оценки жанров экшен и спорт по платформам не равны между собой. И судя по всему различаются кардинально.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Поправь, пожалуйста, выводы после корректировки

# %% [markdown]
# ### 6

# %% [markdown]
#  По итогам проделанных мной работ я провел комплексное исследование для компании "Стримчик". Были рассмотрены многи показатели, определены основные тенденции рынка продаж игр и проверены некоторые гипотезы.
#
#  В ходе исследовательского анализа я выяснил, что пики продаж в игровой индустрии приходилис на 2008 - 2009 годы и в данный момент находится в стагнации, очередной локальный минимум был показан как раз в 2016 году. В рамках сложившейся ситуации на рынке для ведения успешной торговли во время низкого спроса необходимо очень тщательно подбирать основные торговые направления для компании и правильно, и тактично расставлять приоритеты при выборе игровой платформы и жанра игрового продукта, поскольку в таких рыночных условиях успех должен быть гарантирован, а риск скорее всего не будет оправдан. Я изучил наиболее успешные игровые платформы и рассмотрел их ежегодные продажи, актуальным периодом исследования я обозначил промежуток с 2013 года по 2016 год, а наиболее подходящими игровыми платформами под этот временной интервал я обозначил PS4, XOne и PC.
#
#  Продукты на PS4 вышли в продажу еще в 2013 году, и по сей день продажи остаются на выском уровне, несмотря на на минимумы продаж по всему рынку в 2016 году. Новое поколение одной из наиболее популярных платформ пока не анонсировано, поэтому на ближайшие годы PS4 будет показывать стабильно высокие продажи, среди всех выбранных мной платформ обладает лучшими продажами, медианные продажи около 70 млн проданных копий. Игры для серии PS пользуются высочайшим спросом из поколения в поколение новых платформ, уровень доверия к платформе у пользователей высок, можно справедливо сказать, что сделать выбор продуктов на PS4 приоритеным не будет ошибкой.
#
#  Продукты на XOne тоже впервые вышли в 2013 году. Продажи на платформе не такие высокие, как у PS4, но платформу я всё же отношу к актуальным и прибыльным, медианные продажи составляют около 35 млн копий, что является хорошим показателем с учетом общего нисходящего тренда продаж в игровой индустрии. Также можно ожидать умеренный всплеск продаж в следующем году, поскольку ожидается выход новой, более совершенной версии Xbox One X, на которую автоматически будут портированы продукты предназначенные для всего семейства XOne, версия 17 года будет уже третьей по счету. Игровые продукты для серии платформ Xbox также как и PS пользуются традиционной популярностью у пользователей по всему миру.
#
#  Наименее популярной из представленных является платформа PC, она же ПК. Да продажи в среднем меньше, а медианные продажи на уровне 10 млн копий, но игры на ПК выходят стабильно с восьмидесятых годов и показывают стабильные продажи в диапазоне до 20 млн копий и в долгосрочной перспективе будут показывать похожие результаты из года в год. Это предожение было представлено для рассмотрения компанией вариантов продаж независимо от консольных игровых платформ описанных выше. Поскольку в этих консолях со временем на базе собственных ОС появляются игровые магазины, где пользователь не отходя от консоли может приобретать игры. Поэтому рекомендую рассмотреть вариант продажи игровых ключей для всех перечисленных в этом исследовании платформ, а для конкуренции рекомендую приступить к разработке конкурентных предложений для потенциальных покупателей в следующем 2017 году.
#
#  Также я изучил наиболее популярные жанры, с гарантированными высокими продажами. По совокупному объему продаж на выбранных мной платформах лидируют шутеры, экшен и спорт. Но есть одно важное но, высокий обьем продаж в случае с играми жанра экшен обеспечен конкретными успешными релизами, которых в 2017 году может и не быть. Показатели шутеров и спорта с высокой долей вероятности не будут подвержены такой валотильности, как с экшен, и продажи у них будут на предсказуемо высоких уровнях. Также рекомендую рассмотреть помимо этих жанров, те что обладают аналогично высокими медианными продажами, хоть и не с такими высокими шансами на преодоление медианного уровня. Хорошими медианными продажами обладают игры жанра РПГ, спорт, гонки и misc. Все остальные жанры не рекомендую к рассмотрению. А на продукты со всеми вышеописанными жанрами рекоменую обратить внимание, ведь именно за счет их продаж можно добиться хороших финансовых результатов.
#
#  В том числе я проанализировал продажи по регионам, так в случае с жанрами в америке лидируют экшен, шутеры, спорт и платформеры. Большой совокупный обьем продаж и у жанра misc, но на актуальных платформах сейчас у него крайне низкие продажи. В европейском регионе аналогичная ситуация, разве что обьемы продаж практически в два раза меньше, чем на американском рынке. В Японии продажи по жанрам еще меньше, но и ситуация там кардинально другая. Абсолютным лидером по продажам являтся РПГ, популрны в том числе экшен, спорт и платформеры. Поэтому в американском и европейском регионе подготовка маркетинговой стратегии бдует абсолютно идентична,  а ожидания от продаж будут схожими с поправкой на разницу в средних обьемах в продаж в этих регионах. К Японии же нужен более деликатный подход, поэтому наиболее выгодные предложения для японских пользователей рекомендую сосредоточить в особенности в РПГ, но и про другие популярные жанры не следует забывать. В исследовании в любом случае фавориты остаеются шутеры, поскольку обладают как высокими совокупными продажами, так и высокими медианными, но в любом случае важна вариативность, поэтому к не менее перспективнамы жанрам отношу платформеры, спорт, экшен и РПГ.
#
#  Также я провел исследование, где на основе корреляций выснил, что при выборе потенциально прибыльного игрового продукта, компании следует полагаться скорее на отзывы критиков, нежели на оценки пользователей, но зависимость влияния мнения критиков на продажи довольно относительно и не всегда является маркером, возможно, успешного проекта. Но есть один момент, в датасете пристутсвует огромное количество пропусков(почти 70% от общего количества строк) в колонках с оценками и игровым рейтингом, поэтому я не могу гарантировать точность моих наблюдений. Если появится такая возможность, прошу предоставить обновленную версию датасета с меньшим количество пропусков.
#
#  Мной по итогам исследования были проверены и немаловажные гипотезы, по итогам проверки которых выяснилось, что пользователи оценки на платформах XOne и PC существенно  различаются, несмотря на то, что на данных платформах могут пристутствовать одни и те же игры. А вот гипотеза о равенстве пользовательских оценок жанров экшен и спорт подтвердилась, этот важный показатель, поскольку мединные оценки по жанрау у них высокие, что отражает высокое доверие пользователей к данным жанрам.
#
#  В этот раз вывод получился здоровущим...

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# __Комментарий от ревьюера №1__
#
# Договорились. Хорошей практикой является написание в общем выводе всех твоих действий (кратко) по проекту. Ведь вывод раскрывает для заказчика всю твою проделанную работу и за что он платит деньги, даже если ему не интересен весь процесс исследования, то в отчёт он заглянет обязательно.
#
# ---
#
# Так же после исследования, бизнесу нужны будут рекомендации. На какие платформы выпускать игры, на какие жанры ушли в прошлое, а за какими будущее и т.д.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Шикарный вывод. Молодец!)
#
# Не забудь подкорректировать вывод после исправлений
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
# ---
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями и выявляешь выбросы в числовых данных, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Вводная часть
#
# 2) Оформление кода
#
# 3) Неявные дубликаты
#
# 4) Анализ причин возникновения пропусков
#
# 5) Актуальный период (нужно определить актуальный период, и проводить EDA и гипотезы на основании логов актуального периода).
#
# 6) Boxplot
#
# 7) Смотреть на общие продажи лучше через призму медианы
#
# 8) Финальный вывод
#
# 9) Подправить выводы, после изменений
#
# ---
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №2 </b>
#
# ---
#
# Отличная работа, осталось поправить несколько моментов:
#
# ---
#
# Нужно поправить:
#
# 1) Оформление кода
#
# 2) Неявные дубликаты
#
# 3) Актуальный период (нужно определить актуальный период, и проводить EDA и гипотезы на основании логов актуального периода).
#
# 4) Boxplot
#
# 5) Смотреть на общие продажи лучше через призму медианы
#
# 6) Подправить выводы, после изменений
#
# ---
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №3 </b>
#
# ---
#
# Последние штрихи:
#
# ---
#
# Нужно поправить:
#
#
#
# 1) Неявные дубликаты
#
# 2) Смотреть на общие продажи лучше через призму медианы
#
# 3) Подправить выводы, после изменений
#
# ---
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №4 </b>
#
#
#
# ---
#
# Нужно поправить:
#
#
#
# 1) Неявные дубликаты
#
#
# ---
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №5__
#
#
# В остальном всё чудно😊
#
#
# Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊</div>
